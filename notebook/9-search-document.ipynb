# %%
import importlib
import sys
from pathlib import Path

# Find project root whether kernel cwd is repo root or notebook/
PROJECT_ROOT = Path.cwd().resolve()
if (PROJECT_ROOT / "aiengine").is_dir():
    root = PROJECT_ROOT
elif (PROJECT_ROOT.parent / "aiengine").is_dir():
    root = PROJECT_ROOT.parent
else:
    raise RuntimeError("Could not locate project root (aiengine package)")

notebook_dir = root / "notebook"
for path in (root, notebook_dir):
    path_str = str(path)
    if path_str not in sys.path:
        sys.path.insert(0, path_str)

import setup

importlib.reload(setup)  # avoid stale cached setup.py after edits
setup.init(verbose=True)
# Out:
# Project root: /home/dell/Desktop/Agentic-Ai-Django
# aiengine exists: True
# Applied nest_asyncio patch for Jupyter compatibility
# Django setup complete

# %%
import importlib
import ai.agents

importlib.reload(ai.agents)

from ai.agents import get_document_agent

agent = get_document_agent()

# %%
import uuid
from django.contrib.auth.models import User

config = {
    "configurable": {
        "user_id": User.objects.filter(is_superuser=True).first().id,
        "thread_id": uuid.uuid4(),
    }
}

# 1st arg = agent input 
# 2nd arg = config (user_id goes here)
response = agent.invoke(
    {
        "messages": [
            {
                "role": "user",
                "content": "Please search for documents with title containing 'New Meeting Notes'",
            }
        ],
    },
    config,
)

response["messages"]
for msg in response["messages"]:
    print(msg.content)
# Out:
# Please search for documents with title containing 'New Meeting Notes'
#
# [{"id": 18, "title": "New Meeting Notes", "content": "Team sync summary", "active": true, "owner": "admin", "created_at": "2026-08-12 06:58:10 AM", "updated_at": "2026-08-12 07:21:42 AM"}]
# I found 1 document matching **“New Meeting Notes”**:
#
# - **ID:** 18
# - **Title:** New Meeting Notes
# - **Content:** Team sync summary
#
# If you want, I can also help open, update, or summarize it.

# %%
import uuid
from django.contrib.auth.models import User

config = {
    "configurable": {
        "user_id": User.objects.filter(is_superuser=True).first().id,
        "thread_id": uuid.uuid4(),
    }
}

# 1st arg = agent input 
# 2nd arg = config (user_id goes here)
response = agent.invoke(
    {
        "messages": [
            {
                "role": "user",
                "content": "Please delete for documents with title containing 'New Meeting Notes'",
            }
        ],
    },
    config,
)

response["messages"]
for msg in response["messages"]:
    print(msg.content)
# Out:
# Please delete for documents with title containing 'New Meeting Notes'
# I can help identify those documents, but I don’t have a delete tool. I can search for titles containing “New Meeting Notes” and then, if you want, update the matching documents in some way or help you draft a deletion list for manual removal. Would you like me to search for them now?
# I can’t delete documents directly because there’s no delete tool available here.
#
# I can, however, search for documents with titles containing **“New Meeting Notes”** and list them for you. If you want, I can do that now.
