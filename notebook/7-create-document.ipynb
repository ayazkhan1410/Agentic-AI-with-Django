# %%
import importlib
import sys
from pathlib import Path

# Find project root whether kernel cwd is repo root or notebook/
PROJECT_ROOT = Path.cwd().resolve()
if (PROJECT_ROOT / "aiengine").is_dir():
    root = PROJECT_ROOT
elif (PROJECT_ROOT.parent / "aiengine").is_dir():
    root = PROJECT_ROOT.parent
else:
    raise RuntimeError("Could not locate project root (aiengine package)")

notebook_dir = root / "notebook"
for path in (root, notebook_dir):
    path_str = str(path)
    if path_str not in sys.path:
        sys.path.insert(0, path_str)

import setup

importlib.reload(setup)  # avoid stale cached setup.py after edits
setup.init(verbose=True)
# Out:
# Project root: /home/dell/Desktop/Agentic-Ai-Django
# aiengine exists: True
# Applied nest_asyncio patch for Jupyter compatibility
# Django already configured

# %%
import importlib
import ai.agents

importlib.reload(ai.agents)

from ai.agents import get_document_agent

agent = get_document_agent()

# %%
import uuid
from django.contrib.auth.models import User

config = {
    "configurable": {
        "user_id": User.objects.filter(is_superuser=True).first().id,
        "thread_id": uuid.uuid4(),
    }
}

# 1st arg = agent input 
# 2nd arg = config (user_id goes here)
response = agent.invoke(
    {
        "messages": [
            {
                "role": "user",
                "content": "Give me detail of the conjuring"
            }
        ],
    },
    config,
)

response["messages"]
for msg in response["messages"]:
    print(msg.content)
# Out:
# Give me detail of the conjuring
# “The Conjuring” usually refers to the 2013 horror film directed by James Wan. Here’s a detailed overview:
#
# ### Basic info
# - **Title:** *The Conjuring*
# - **Release year:** 2013
# - **Director:** James Wan
# - **Genre:** Supernatural horror
# - **Main cast:** Vera Farmiga, Patrick Wilson
#
# ### Plot summary
# The film follows **Ed and Lorraine Warren**, a real-life paranormal investigator couple, as they are called to help the **Perron family**, who have moved into an old farmhouse in Rhode Island. After strange and terrifying events begin happening in the house—unexplained noises, mysterious scratches, and violent supernatural activity—the Warrens investigate and discover that the home is haunted by a dark presence tied to a witch named **Bathsheba Sherman**.
#
# ...

# %%
import uuid
from django.contrib.auth.models import User

config = {
    "configurable": {
        "user_id": User.objects.filter(is_superuser=True).first().id,
        "thread_id": uuid.uuid4(),
    }
}

# 1st arg = agent input 
# 2nd arg = config (user_id goes here)
response = agent.invoke(
    {
        "messages": [
            {
                "role": "user",
                "content": "Now please create document of the conjuring along with the details"
            }
        ],
    },
    config,
)

response["messages"]
for msg in response["messages"]:
    print(msg.content)
# Out:
# Now please create document of the conjuring along with the details
#
# ...

# %%
import uuid
from django.contrib.auth.models import User

config = {
    "configurable": {
        "user_id": User.objects.filter(is_superuser=True).first().id,
        "thread_id": uuid.uuid4(),
    }
}

# 1st arg = agent input 
# 2nd arg = config (user_id goes here)
response = agent.invoke(
    {
        "messages": [
            {
                "role": "user",
                "content": "Please list down all the documents alomng with the content"
            }
        ],
    },
    config,
)

response["messages"]
for msg in response["messages"]:
    print(msg.content)
# Out:
# USER ID IN GET DOCUMENTS: 1
# Please list down all the documents alomng with the content
#
# [{"id": 5, "title": "Deployment Checklist", "content": "Steps for staging and production release.", "active": true, "owner": "admin", "created_at": "2026-06-11 02:31:12 PM", "updated_at": "2026-06-11 02:31:12 PM"}, {"id": 4, "title": "API Design Notes", "content": "REST endpoints and serializer conventions.", "active": true, "owner": "admin", "created_at": "2026-06-11 02:31:12 PM", "updated_at": "2026-06-11 02:31:12 PM"}, {"id": 3, "title": "Project Requirements", "content": "Outline of core features and milestones.", "active": true, "owner": "admin", "created_at": "2026-06-11 02:31:12 PM", "updated_at": "2026-06-11 02:31:12 PM"}, {"id": 2, "title": "Test Document", "content": "This is a test document", "active": true, "owner": "admin", "created_at": "2026-06-09 02:17:17 PM", "updated_at": "2026-06-11 01:18:50 PM"}]
# Here are the documents and their content:
#
# 1. **Deployment Checklist**
# ...
